# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\anshu\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\anshu\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_csv("customer_churn_data.csv")

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4             NaN       2208.32          No   Yes

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       1000 non-null   int64
#  1   Age              1000 non-null   int64
#  2   Gender           1000 non-null   str
#  3   Tenure           1000 non-null   int64
#  4   MonthlyCharges   1000 non-null   float64
#  5   ContractType     1000 non-null   str
#  6   InternetService  703 non-null    str
#  7   TotalCharges     1000 non-null   float64
#  8   TechSupport      1000 non-null   str
#  9   Churn            1000 non-null   str
# dtypes: float64(2), int64(3), str(5)
# memory usage: 78.3 KB

# %%
df["InternetService"] =  df["InternetService"].fillna("")

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49    Male       4           88.35  Month-to-Month
# 1           2   43    Male       0           36.67  Month-to-Month
# 2           3   51  Female       2           63.79  Month-to-Month
# 3           4   60  Female       8          102.34        One-Year
# 4           5   42    Male      32           69.01  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic        353.40         Yes   Yes
# 1     Fiber Optic          0.00         Yes   Yes
# 2     Fiber Optic        127.58          No   Yes
# 3             DSL        818.72         Yes   Yes
# 4                       2208.32          No   Yes

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#         CustomerID          Age      Tenure  MonthlyCharges  TotalCharges
# count  1000.000000  1000.000000  1000.00000     1000.000000   1000.000000
# mean    500.500000    44.674000    18.97300       74.391290   1404.364060
# std     288.819436     9.797741    18.89257       25.712083   1571.755048
# min       1.000000    12.000000     0.00000       30.000000      0.000000
# 25%     250.750000    38.000000     5.00000       52.357500    345.217500
# 50%     500.500000    45.000000    13.00000       74.060000    872.870000
# 75%     750.250000    51.000000    26.00000       96.102500   1900.175000
# max    1000.000000    83.000000   122.00000      119.960000  12416.250000

# %%
numerical_columns_data = df.select_dtypes(include=["number"])

# %%
numerical_columns_data.corr()
# Out:
#                 CustomerID       Age    Tenure  MonthlyCharges  TotalCharges
# CustomerID        1.000000  0.036730 -0.018585       -0.030504     -0.027490
# Age               0.036730  1.000000  0.000472        0.006362     -0.001896
# Tenure           -0.018585  0.000472  1.000000       -0.014552      0.894868
# MonthlyCharges   -0.030504  0.006362 -0.014552        1.000000      0.304893
# TotalCharges     -0.027490 -0.001896  0.894868        0.304893      1.000000

# %%
df
# Out:
#      CustomerID  Age  Gender  Tenure  MonthlyCharges    ContractType  \
# 0             1   49    Male       4           88.35  Month-to-Month
# 1             2   43    Male       0           36.67  Month-to-Month
# 2             3   51  Female       2           63.79  Month-to-Month
# 3             4   60  Female       8          102.34        One-Year
# 4             5   42    Male      32           69.01  Month-to-Month
# ..          ...  ...     ...     ...             ...             ...
# 995         996   42    Male      41           37.14  Month-to-Month
# 996         997   62    Male       9           80.93  Month-to-Month
# 997         998   51  Female      15          111.72  Month-to-Month
# 998         999   39    Male      68           65.67        One-Year
# 999        1000   50    Male       1           56.67  Month-to-Month
#
#     InternetService  TotalCharges TechSupport Churn
# 0       Fiber Optic        353.40         Yes   Yes
# 1       Fiber Optic          0.00         Yes   Yes
# 2       Fiber Optic        127.58          No   Yes
# 3               DSL        818.72         Yes   Yes
# 4                         2208.32          No   Yes
# ..              ...           ...         ...   ...
# 995     Fiber Optic       1522.74         Yes   Yes
# 996                        728.37          No   Yes
# 997     Fiber Optic       1675.80         Yes   Yes
# 998                       4465.56          No   Yes
# 999                         56.67          No   Yes
#
# [1000 rows x 10 columns]

# %%
# %pip install matplotlib 
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: matplotlib in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.25 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\anshu\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\anshu\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\anshu\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df["Churn"].value_counts().plot(kind="pie")
plt.title("Churn (Yes/No)")
plt.ylabel("")
plt.show()

# %%
df.groupby("Churn")["MonthlyCharges"].mean()
# Out:
# Churn
# No     62.54641
# Yes    75.96077
# Name: MonthlyCharges, dtype: float64

# %%
df.groupby("Churn")["Age"].mean()
# Out:
# Churn
# No     43.487179
# Yes    44.831257
# Name: Age, dtype: float64

# %%
df.groupby("ContractType")["MonthlyCharges"].mean().plot(kind="bar")
plt.ylabel("Average Monthly Charges")
plt.xlabel("Contract Type")
plt.title("Average Monthly Charges by Contract Type")
plt.show()

# %% [markdown]
# At lower terms the charges reduces

# %%
df.head(2)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
# 1           2   43   Male       0           36.67  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes
# 1     Fiber Optic           0.0         Yes   Yes

# %%
plt.hist(df["MonthlyCharges"])
plt.title("Histogram of Monthly Charges")
plt.show()

# %%
plt.hist(df["Tenure"])
plt.title("Histogram of Tenure")
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Tenure', 'MonthlyCharges',
#        'ContractType', 'InternetService', 'TotalCharges', 'TechSupport',
#        'Churn'],
#       dtype='str')

# %%
df.head(1)
# Out:
#    CustomerID  Age Gender  Tenure  MonthlyCharges    ContractType  \
# 0           1   49   Male       4           88.35  Month-to-Month
#
#   InternetService  TotalCharges TechSupport Churn
# 0     Fiber Optic         353.4         Yes   Yes

# %%
y = df[[ "Churn"]]
X = df[["Age", "Tenure", "MonthlyCharges", "Gender"]]

# %%
X #1 for female and 0 for male
# Out:
#      Age  Tenure  MonthlyCharges  Gender
# 0     49       4           88.35    Male
# 1     43       0           36.67    Male
# 2     51       2           63.79  Female
# 3     60       8          102.34  Female
# 4     42      32           69.01    Male
# ..   ...     ...             ...     ...
# 995   42      41           37.14    Male
# 996   62       9           80.93    Male
# 997   51      15          111.72  Female
# 998   39      68           65.67    Male
# 999   50       1           56.67    Male
#
# [1000 rows x 4 columns]

# %%
X["Gender"] = X["Gender"].apply(lambda x: 1 if x == "Female" else 0)

# %%
y
# Out:
#     Churn
# 0     Yes
# 1     Yes
# 2     Yes
# 3     Yes
# 4     Yes
# ..    ...
# 995   Yes
# 996   Yes
# 997   Yes
# 998   Yes
# 999   Yes
#
# [1000 rows x 1 columns]

# %%
y.head(2)
# Out:
#   Churn
# 0   Yes
# 1   Yes

# %%
y["Churn"] = y["Churn"].apply(lambda x: 1 if x == "Yes" else 0)

# %%
# %pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.5.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.0)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\anshu\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X
# Out:
#      Age  Tenure  MonthlyCharges  Gender
# 0     49       4           88.35       0
# 1     43       0           36.67       0
# 2     51       2           63.79       1
# 3     60       8          102.34       1
# 4     42      32           69.01       0
# ..   ...     ...             ...     ...
# 995   42      41           37.14       0
# 996   62       9           80.93       0
# 997   51      15          111.72       1
# 998   39      68           65.67       0
# 999   50       1           56.67       0
#
# [1000 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
import joblib
joblib.dump(scaler, "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.metrics import accuracy_score
def modelperformance(predictions):
    print("Accuracy Score on the model is {}", accuracy_score(y_test, predictions))

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model = LogisticRegression()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
log_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X
# Out:
#      Age  Tenure  MonthlyCharges  Gender
# 0     49       4           88.35       0
# 1     43       0           36.67       0
# 2     51       2           63.79       1
# 3     60       8          102.34       1
# 4     42      32           69.01       0
# ..   ...     ...             ...     ...
# 995   42      41           37.14       0
# 996   62       9           80.93       0
# 997   51      15          111.72       1
# 998   39      68           65.67       0
# 999   50       1           56.67       0
#
# [1000 rows x 4 columns]

# %%
y_pred = log_model.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy Score on the model is {} 0.895

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
param_grid = {
    "n_neighbors": [3, 5, 7, 9],
    "weights": ["uniform", "distance"],
}

# %%
gridkn = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)

# %%
gridkn.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': [3, 5, 7, 9],
#                          'weights': ['uniform', 'distance']})

# %%
gridkn.best_params_
# Out:
# {'n_neighbors': 9, 'weights': 'distance'}

# %%
y_pred = gridkn.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy Score on the model is {} 0.9

# %%
from sklearn.svm import SVC

# %%
svm = SVC()

# %%
param_grid = {
    "C" : [0.01, 0.1, 0.5, 1],
    "kernel" : ["linear", "rbf", "poly"]
}

# %%
gridsvc = GridSearchCV(SVC(), param_grid, cv=5)

# %%
gridsvc.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 0.5, 1],
#                          'kernel': ['linear', 'rbf', 'poly']})

# %%
gridsvc.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %%
y_pred = gridsvc.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy Score on the model is {} 0.895

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
param_grid = {
    "criterion": ["gini", "entropy"],
    "splitter": ["best", "random"],
    "max_depth": [None, 5, 10, 15],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 4]
}

# %%
grid_tree = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)

# %%
grid_tree.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'splitter': ['best', 'random']})

# %%
grid_tree.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'splitter': 'random'}

# %%
y_pred = grid_tree.predict(X_test)

# %%
modelperformance(y_pred)
# Out:
# Accuracy Score on the model is {} 0.895

# %%
from sklearn.ensemble import RandomForestClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[341], line 1
# ----> 1 from sklearn.embedding import RandomForestClassifier
#
# ModuleNotFoundError: No module named 'sklearn.embedding'
